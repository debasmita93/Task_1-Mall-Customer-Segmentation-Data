# %% [markdown]
# ## MALL CUSTOMER SEGMENTATION DATA

# %%
# Data Analysis
import pandas as pd
import numpy as np

# %%
# Loading the "Mall_Customers" dataset
data = pd.read_csv(r"C:\Users\sahad\Downloads\Mall_Customers.csv")
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
data.head(), data.tail()
# Out:
# (   CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
#  0           1    Male   19                  15                      39
#  1           2    Male   21                  15                      81
#  2           3  Female   20                  16                       6
#  3           4  Female   23                  16                      77
#  4           5  Female   31                  17                      40,
#       CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
#  195         196  Female   35                 120                      79
#  196         197  Female   45                 126                      28
#  197         198    Male   32                 126                      74
#  198         199    Male   32                 137                      18
#  199         200    Male   30                 137                      83)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
data.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %% [markdown]
# ## Removing the missing values present in the dataset

# %%
# Handling missing (null) values
# Checking if there is any presence of null values in the dataset
data.isnull()
# Out:
#      CustomerID  Gender    Age  Annual Income (k$)  Spending Score (1-100)
# 0         False   False  False               False                   False
# 1         False   False  False               False                   False
# 2         False   False  False               False                   False
# 3         False   False  False               False                   False
# 4         False   False  False               False                   False
# ..          ...     ...    ...                 ...                     ...
# 195       False   False  False               False                   False
# 196       False   False  False               False                   False
# 197       False   False  False               False                   False
# 198       False   False  False               False                   False
# 199       False   False  False               False                   False
#
# [200 rows x 5 columns]

# %%
# Handling missing values
data.isnull().sum()
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# ## We found that there are no missing (or null) values in the dataset

# %% [markdown]
# ## Checking if there are any duplicate values in the dataset, and removing them for further data analysis

# %%
# Dropping the duplicate values present in the dataset
data.drop_duplicates()
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# ## We found that there are no duplicate values in the dataset. Hence, the dataset is cleaned !

# %%
# Standardizing the datatype of "Gender" column
data = pd.Series("Gender", dtype = "str")
data
# Out:
# 0    Gender
# dtype: object

# %%
# Renaming the column names to lower-case and without any spaces
data = pd.DataFrame(pd.read_csv(r"C:\Users\sahad\Downloads\Mall_Customers.csv"))
data.rename(columns = {"CustomerID": "customer_id", "Gender": "gender", "Age": "age", "Annual Income (k$)": "annual_income", "Spending Score (1-100)": "spending_score"}, inplace = True)
data
# Out:
#      customer_id  gender  age  annual_income  spending_score
# 0              1    Male   19             15              39
# 1              2    Male   21             15              81
# 2              3  Female   20             16               6
# 3              4  Female   23             16              77
# 4              5  Female   31             17              40
# ..           ...     ...  ...            ...             ...
# 195          196  Female   35            120              79
# 196          197  Female   45            126              28
# 197          198    Male   32            126              74
# 198          199    Male   32            137              18
# 199          200    Male   30            137              83
#
# [200 rows x 5 columns]

# %%
# Checking the datatypes of each column in the datset
data.dtypes
# Out:
# customer_id        int64
# gender            object
# age                int64
# annual_income      int64
# spending_score     int64
# dtype: object

# %% [markdown]
# ## Therefore, the data is now pre-processed fully !
